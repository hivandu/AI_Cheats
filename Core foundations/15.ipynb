# %% [markdown]
# ## 支持向量机 SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
label_a = np.random.normal(6, 2, size=(50, 2))

# %%
label_b = np.random.normal(-6, 2, size=(50, 2))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

# %%
label_a_x = label_a[:, 0]
label_b_x = label_b[:, 0]

# %%
def f(x, w, b):
    return w * x - b

# %%
w_and_b = []
for i in range(100): 
    w, b = (np.random.random(size=(1, 2)) * 10 - 5)[0]
    if np.max(f(label_a_x, w, b)) <= -1 and np.min(f(label_b_x, w, b)) >= 1:
        print(w, b)
        w_and_b.append((w, b))
# Out:
# -3.898571414742861 1.3639086192443015
# -1.4143109993346625 -1.8382412572396243
# -4.013926457408218 4.583863614502034
# -2.784130754849822 -1.2948010530405596
# -4.696064287415897 -1.0165971103219293
# -2.3156872234331773 3.542892253346352
# -1.7073636942910122 3.5089540868022837
# -2.423996472991927 0.20372877810608436
# -3.4874540510565555 2.313983281989791
# -2.2171685886236494 -0.026606908918953565
# -1.4138887029361955 2.722295323814736
# -2.7757804974806732 2.491031782645803
# -1.470419731195347 2.9776520475927546
# -3.4601909696099984 -4.636288181702835
# -4.526569445406094 -2.3722389776702277
# -3.574530821210402 1.184123986926143
# -3.701690664971963 3.2510519308721335
# -2.40177508378012 -3.9207499893722564
# -2.6119757169474402 -3.429432706933413
# -3.3292429433881807 4.981859396514103
# -2.730616284150776 3.840138139823967
# -3.863705925809878 3.1311184433283543
# -4.509206317120075 2.409025237778808
# -3.224248486344111 -1.4052614979208498
# -3.02195505818318 -0.23301490307046357
# -3.067301305130151 0.1347439373112831
# -1.8816707403578201 2.114375671494681
# -3.314817075087877 1.1096107468434013
# -4.877581383300936 -1.3079276608240975
# -2.645487684903358 2.9285043139436535
# -3.9802056467768576 1.839281643755891
# -2.472274958114833 -4.164786500085331
# -4.4242581261107 -1.0347836408753333
# -1.6135255807355287 0.9135107246565184
# -2.456043587021476 4.4039570176835365
# -3.191801858559302 -1.4528054265396895
# -3.5630365474540615 -0.1845205474647651
# -2.8183334437001104 1.4331531734939418
# -4.571335560068281 4.115568858404991
# -2.282254962819689 4.274525017117826
# -1.2586409823883171 0.5767497260572458
# -2.126421837235657 -1.3543249738204608

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

for w, b in w_and_b:
    x = np.concatenate((label_a_x, label_b_x))
    plt.plot(x, f(x, w, b))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

w, b = sorted(w_and_b, key=lambda t: abs(t[0]))[0]
x = np.concatenate((label_a_x, label_b_x))
plt.plot(x, f(x, w, b))

# %% [markdown]
# ![欢迎订阅：坍缩的奇点](../assets/Capture-2023-11-02-164446.png)
