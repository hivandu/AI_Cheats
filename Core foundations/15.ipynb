# %% [markdown]
# ## 支持向量机 SVM

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
label_a = np.random.normal(6, 2, size=(50, 2))

# %%
label_b = np.random.normal(-6, 2, size=(50, 2))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

# %%
label_a_x = label_a[:, 0]
label_b_x = label_b[:, 0]

# %%
def f(x, w, b):
    return w * x - b

# %%
w_and_b = []
for i in range(100): 
    w, b = (np.random.random(size=(1, 2)) * 10 - 5)[0]
    if np.max(f(label_a_x, w, b)) <= -1 and np.min(f(label_b_x, w, b)) >= 1:
        print(w, b)
        w_and_b.append((w, b))
# Out:
# -1.7719462032823161 -0.6492858337443508
# -1.201288316082846 -0.8886845188103321
# -4.728710166545388 -4.570781992900499
# -4.791999731611353 1.0787845568162329
# -2.701222253638277 0.5956043936463908
# -3.7919392895114665 1.4854984099837552
# -3.565931032786155 -2.812621442439295
# -3.605120479608445 0.2901998296605708
# -2.4144725878902937 0.1560650479247192
# -4.961763914965105 -0.21526465240151893
# -3.1592989862330887 2.0834065020766612
# -3.426635980550804 -4.06373022537121
# -2.365082938280948 0.9061588936510532
# -2.928135594624779 -1.70948585943011
# -4.832361792537157 3.6591663809256314
# -3.6350489151020096 3.8208689632595547
# -2.739879115671507 0.3753263849804185
# -4.122295222344791 -0.2419669246148981
# -3.9541288264648546 -4.294230668240565
# -3.858523612653122 0.3180735674361399
# -2.5171742411387035 -3.197603600662079
# -2.924033399760726 -2.669536317449789
# -3.9752506672978614 -2.8468482458124167
# -2.0307913814186698 0.24883952718954383
# -1.980558800512763 0.37593601660097065
# -2.8821605842886866 -2.216059534358993
# -2.3015178984785734 -2.901391586228874
# -2.377517116079375 -2.9473750649306343
# -2.851186255102809 -3.8345069016862556

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

for w, b in w_and_b:
    x = np.concatenate((label_a_x, label_b_x))
    plt.plot(x, f(x, w, b))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

w, b = sorted(w_and_b, key=lambda t: abs(t[0]))[0]
x = np.concatenate((label_a_x, label_b_x))
plt.plot(x, f(x, w, b))

# %% [markdown]
# ![欢迎订阅：坍缩的奇点](../assets/Capture-2023-11-02-164446.png)
