# %% [markdown]
# ## 支持向量机 SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
label_a = np.random.normal(6, 2, size=(50, 2))

# %%
label_b = np.random.normal(-6, 2, size=(50, 2))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

# %%
label_a_x = label_a[:, 0]
label_b_x = label_b[:, 0]

# %%
def f(x, w, b):
    return w * x - b

# %%
w_and_b = []
for i in range(100): 
    w, b = (np.random.random(size=(1, 2)) * 10 - 5)[0]
    if np.max(f(label_a_x, w, b)) <= -1 and np.min(f(label_b_x, w, b)) >= 1:
        print(w, b)
        w_and_b.append((w, b))
# Out:
# -4.887944175220099 -0.24197077574442982
# -4.303736975157254 -1.7067098513175605
# -4.197140370330143 0.9220172784034819
# -3.3817878489634423 -2.37525415808686
# -3.9499362241468248 4.092626991366792
# -4.09487096745424 3.0472330244467543
# -2.678973503053447 1.5927848048109974
# -4.845093750744484 -2.2826501129637853
# -4.999556772456555 -2.2899863843334445
# -2.0787361745326116 1.1838092502129962
# -3.786451899399388 4.939407868052895
# -3.9722086943734802 -3.2063620345829333
# -4.273204596252026 1.7679439433774498
# -3.404297177758271 2.9774009573895563
# -3.427741230560671 2.7114035528991387
# -4.339400273514125 2.0669078955895994
# -2.4380402270264945 1.4426094848194637
# -3.8738618924233936 2.2787421025712113
# -4.7517210234300205 -0.8561590080269843

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

for w, b in w_and_b:
    x = np.concatenate((label_a_x, label_b_x))
    plt.plot(x, f(x, w, b))

# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))

w, b = sorted(w_and_b, key=lambda t: abs(t[0]))[0]
x = np.concatenate((label_a_x, label_b_x))
plt.plot(x, f(x, w, b))

# %% [markdown]
# ![欢迎订阅：坍缩的奇点](../assets/Capture-2023-11-02-164446.png)
